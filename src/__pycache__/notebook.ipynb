# %% [markdown]
# ## Proyecto Final: Análisis de Cancelaciones Hoteleras

# %% [markdown]
# Objetivo: Identificar patrones que nos ayuden a predecir cancelaciones y optimizar la gestión del hotel.

# %%
import sys

sys.path.append('./src') 

from data_loader import cargar_datos
from db_manager import crear_db_y_tabla, consultar_datos

# Carga de datos
df = cargar_datos()

# Creacion de la BBDD 
conexion = crear_db_y_tabla(df)

#  Ejemplo de cómo se pueden hacer consultas desde aquí
resultado = consultar_datos("SELECT hotel, COUNT(*) as total FROM reservas GROUP BY hotel")
print(resultado)
# Out:
# ¡Éxito! Datos cargados correctamente.
# ¡Base de datos y tabla 'reservas' creadas correctamente!
#           hotel  total
# 0    City Hotel  79330
# 1  Resort Hotel  40060
